# %% [markdown]
# <h2 style='color:blue' align="center">Deep Learning</h2>

# %% [markdown]
# ## Formula:
# z = w1*x1 + w2*x2+....wn*xn + b
# f(z)--Activation--- step function, relu, sigmoid
# 👉 This is single neuron decision

# %%
# LAB 1: Single Layer Perceptron (Manual)

import numpy as np

# Inputs
X = np.array([2, 3])

# Weights
W = np.array([0.5, 0.5])

# Bias
b = 1

# Weighted sum
z = np.dot(X, W) + b

# Activation (Step Function)
output = 1 if z > 0 else 0

print("Weighted Sum:", z)
print("Output:", output)

# %% [markdown]
# ## LAB 2: Change weights and bias

# %%
# LAB 2: Change weights and bias

import numpy as np

X = np.array([2, 3])

# Try different weights
W = np.array([1, -1])
b = -1

z = np.dot(X, W) + b

output = 1 if z > 0 else 0

print("z:", z)
print("Output:", output)
